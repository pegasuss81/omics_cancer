# %% [markdown]
# # 01 - EDA (Toy)

# %%
import pandas as pd
expr=pd.read_csv('../data/toy_expression.csv',index_col=0)
mut=pd.read_csv('../data/toy_mutations.csv',index_col=0)
lab=pd.read_csv('../data/toy_labels.csv')
expr.shape, mut.shape, lab['phenotype'].value_counts()
